# %%
import bq_helper
# create a helper object for our bigquery dataset
chicago_crime = bq_helper.BigQueryHelper(active_project= "bigquery-public-data", 
                                       dataset_name = "chicago_crime")
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %%
chicago_crime.list_tables()
# Out:
# ['crime']

# %%
chicago_crime.table_schema("crime")
# Out:
#                     name                        ...                                                                description
# 0             unique_key                        ...                                          Unique identifier for the record.
# 1            case_number                        ...                          The Chicago Police Department RD Number (Recor...
# 2                   date                        ...                          Date when the incident occurred. this is somet...
# 3                  block                        ...                          The partially redacted address where the incid...
# 4                   iucr                        ...                          The Illinois Unifrom Crime Reporting code. Thi...
# 5           primary_type                        ...                                  The primary description of the IUCR code.
# ...

# %%
chicago_crime.head("crime")
# Out:
#    unique_key              ...                                     location
# 0    11719135              ...                                         None
# 1    11693097              ...                 (41.82689451, -87.662705011)
# 2    11677710              ...                (41.819958109, -87.723981548)
# 3    11665284              ...                (41.728646864, -87.585472909)
# 4    11730775              ...                                         None
#
# [5 rows x 22 columns]

# %%
chicago_crime.head("crime",selected_columns="description",num_rows=10)
# Out:
#                            description
# 0                ILLEGAL USE CASH CARD
# 1               TRUCK, BUS, MOTOR HOME
# 2                       NON-AGGRAVATED
# 3         POSSESSION OF DRUG EQUIPMENT
# 4  FINANCIAL IDENTITY THEFT OVER $ 300
# 5             FALSE/STOLEN/ALTERED TRP
# 6      ARMED WHILE UNDER THE INFLUENCE
# 7            THEFT BY LESSEE,MOTOR VEH
# 8                POSS: SYNTHETIC DRUGS
# 9       AGGRAVATED:KNIFE/CUTTING INSTR

# %%
help(chicago_crime)
# Out:
# Help on BigQueryHelper in module bq_helper object:
#
# class BigQueryHelper(builtins.object)
#  |  Helper class to simplify common BigQuery tasks like executing queries,
#  |  showing table schemas, etc without worrying about table or dataset pointers.
#  |
#  |  See the BigQuery docs for details of the steps this class lets you skip:
#  |  https://googlecloudplatform.github.io/google-cloud-python/latest/bigquery/reference.html
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, active_project, dataset_name, max_wait_seconds=180)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  estimate_query_size(self, query)
#  |      Estimate gigabytes scanned by query.
#  |      Does not consider if there is a cached query table.
#  |      See https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs#configuration.dryRun
#  |
#  |  head(self, table_name, num_rows=5, start_index=None, selected_columns=None)
# ...

# %%
# BigQuery Standard SQL requires backticks around the table name ``
query = """SELECT count(unique_key)
            FROM `bigquery-public-data.chicago_crime.crime`
            """

chicago_crime.estimate_query_size(query)
# Out:
# 0.05140863358974457

# %%
no=chicago_crime.query_to_pandas_safe(query, max_gb_scanned=0.1)

# %%
no
# Out:
#        f0_
# 0  6899950

# %%
query_1 = """SELECT date
                FROM `bigquery-public-data.chicago_crime.crime`
                WHERE district = 9"""
chicago_crime.estimate_query_size(query_1)
# Out:
# 0.10281691700220108

# %%
date_crime = chicago_crime.query_to_pandas_safe(query_1,max_gb_scanned=0.1)
# Out:
# Query cancelled; estimated size of 0.10281691700220108 exceeds limit of 0.1 GB

# %%
date_crime
